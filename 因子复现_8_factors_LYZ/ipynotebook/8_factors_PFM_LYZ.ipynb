# %%
from jaqs_fxdayu.util import dp
from jaqs.data.dataapi import DataApi

api = DataApi(addr = 'tcp://data.tushare.org:8910')
api.login("2163752900",
         "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MjMzOTQ3NjgwNjYiLCJpc3MiOiJhdXRoMCIsImlkIjoiMjE2Mzc1MjkwMCJ9.pReKJ97rf2P9ACLibxS0AHSUiEhvTxNeMRSQTWWDeYM")

start = 20130101
end = 20180101

ZZ800_id = dp.index_cons(api, "000906.SH", start, end)

stock_symbol = list(set(ZZ800_id.symbol.values))

# %%
factor_list = ['volume', 'turnover']
check_factor = ','.join(factor_list)

# %%
import jaqs_fxdayu
jaqs_fxdayu.patch_all()
from jaqs.data import DataView
from jaqs.data import RemoteDataService
from jaqs_fxdayu.data.dataservice import LocalDataService
import os
import numpy as np
import warnings
warnings.filterwarnings("ignore")

dataview_folder = r'E:\Quant\fxdayu\Git\data'
dv = DataView()
ds = LocalDataService(fp=dataview_folder)

dv_props = {'start_date': start, 'end_date': end, 'symbol':','.join(stock_symbol),
         'fields': check_factor,
         'freq': 1,
         "prepare_fields": True}

dv.init_from_config(dv_props, data_api=ds)
dv.prepare_data()
# Out:
# E:\anaconda36\lib\importlib\__init__.py:126: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   return _bootstrap._gcd_import(name[level:], package, level)
# E:\anaconda36\lib\site-packages\jaqs\research\signaldigger\plotting.py:10: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "E:\anaconda36\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "E:\anaconda36\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "E:\anaconda36\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
# ...

# %%
#-------------------------- 获取分类数据 -----------------------#

# %%
dv.add_field('sw1')
# Out:
# True

# %%
sw1 = dv.get_ts('sw1')
sw1.tail()
# Out:
# symbol     000001.SZ 000002.SZ 000006.SZ 000008.SZ 000009.SZ 000012.SZ  \
# trade_date
# 20171225          银行       房地产       房地产      机械设备        综合      建筑材料
# 20171226          银行       房地产       房地产      机械设备        综合      建筑材料
# 20171227          银行       房地产       房地产      机械设备        综合      建筑材料
# 20171228          银行       房地产       房地产      机械设备        综合      建筑材料
# 20171229          银行       房地产       房地产      机械设备        综合      建筑材料
#
# symbol     000021.SZ 000024.SZ 000025.SZ 000027.SZ    ...    603833.SH  \
# trade_date                                            ...
# 20171225         计算机       nan        汽车      公用事业    ...         轻工制造
# 20171226         计算机       nan        汽车      公用事业    ...         轻工制造
# 20171227         计算机       nan        汽车      公用事业    ...         轻工制造
# 20171228         计算机       nan        汽车      公用事业    ...         轻工制造
# 20171229         计算机       nan        汽车      公用事业    ...         轻工制造
#
# ...

# %%
dict_classify = {'480000': '银行', '430000': '房地产', '460000': '休闲服务', '640000': '机械设备', '240000': '有色金属', '510000': '综合', '410000': '公用事业', '450000': '商业贸易', '730000': '通信', '330000': '家用电器', '720000': '传媒', '630000': '电气设备', '270000': '电子', '490000': '非银金融', '370000': '医药生物', '710000': '计算机', '280000': '汽车', '340000': '食品饮料', '220000': '化工', '210000': '采掘', '230000': '钢铁', '650000': '国防军工', '110000': '农林牧渔', '420000': '交通运输', '620000': '建筑装饰', '350000': '纺织服装', '610000': '建筑材料', '360000': '轻工制造'}

# %%
sw1_name = sw1.replace(dict_classify)
sw1_name.tail()
# Out:
# symbol     000001.SZ 000002.SZ 000006.SZ 000008.SZ 000009.SZ 000012.SZ  \
# trade_date
# 20171225          银行       房地产       房地产      机械设备        综合      建筑材料
# 20171226          银行       房地产       房地产      机械设备        综合      建筑材料
# 20171227          银行       房地产       房地产      机械设备        综合      建筑材料
# 20171228          银行       房地产       房地产      机械设备        综合      建筑材料
# 20171229          银行       房地产       房地产      机械设备        综合      建筑材料
#
# symbol     000021.SZ 000024.SZ 000025.SZ 000027.SZ    ...    603833.SH  \
# trade_date                                            ...
# 20171225         计算机       nan        汽车      公用事业    ...         轻工制造
# 20171226         计算机       nan        汽车      公用事业    ...         轻工制造
# 20171227         计算机       nan        汽车      公用事业    ...         轻工制造
# 20171228         计算机       nan        汽车      公用事业    ...         轻工制造
# 20171229         计算机       nan        汽车      公用事业    ...         轻工制造
#
# ...

# %%
#------------------------------ 输入8个因子 -------------------------------#

# %%
alpha13 = dv.add_formula('alpha13',"(high*low)^0.5-vwap"
                        , is_quarterly=False, add_data=True)

# %%
alpha39 = dv.add_formula('alpha39',
                        "((Rank(Decay_linear(Delta((close), 2),8)) - Rank(Decay_linear(Correlation(((vwap * 0.3) + (open * 0.7)),Ts_Sum(Ts_Mean(volume,180), 37), 14), 12))) * -1)"
                        ,is_quarterly = False, add_data = True)

# %%
def SMA(A,n,m):
    alpha = m/n
    return A.ewm(alpha=alpha, adjust=False).mean()

alpha109 = dv.add_formula('alpha109', 
               "SMA(high-low,{},{})/SMA(SMA(high-low,{},{}),{},{})".format(10,2,10,2,10,2)
             , is_quarterly=False, add_data=True,
             register_funcs={"SMA":SMA}
             )

# %%
alpha131 = dv.add_formula('alpha131',"(Rank(Delta(vwap, 1))^Ts_Rank(Correlation(close,Ts_Mean(volume,50), 18), 18))"
                         ,is_quarterly=False, add_data=True)

# %%
alpha132 = dv.add_formula('alpha132',"Ts_Mean(turnover,20)"
                         ,is_quarterly=False, add_data=True)

# %%
def SMA(A,n,m):
    alpha = m/n
    return A.ewm(alpha=alpha, adjust=False).mean()

alpha169 = dv.add_formula('alpha169',"SMA(Ts_Mean(Delay(SMA(close-Delay(close,1),9,1),1),12) - Ts_Mean(Delay(SMA(close-Delay(close,1),9,1),1),26),10,1)"
             , is_quarterly=False, add_data=True,
             register_funcs={"SMA":SMA})

# %%
EquityTRate = dv.add_formula('EquityTRate_J','oper_rev/(tot_assets-total_liab)',
                            is_quarterly=False, add_data=True)
# Out:
# Variable [oper_rev] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000522.SZ, 000527.SZ, 000562.SZ, 000748.SZ, 600005.SH, 600832.SH, 601268.SH, 601299.SH
# Query data - quarterly fields prepared.
# Query data - query...
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000522.SZ, 000527.SZ, 000562.SZ, 000748.SZ, 600005.SH, 600832.SH, 601268.SH, 601299.SH
# Query data - quarterly fields prepared.
# Variable [tot_assets] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000522.SZ, 000527.SZ, 000562.SZ, 000748.SZ, 600005.SH, 600832.SH, 601268.SH, 601299.SH
# Query data - quarterly fields prepared.
# Variable [total_liab] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# WARNING: some data is unavailable:
# ...

# %%
PCF = dv.add_formula('PCF_J','capital_stk/ncf_oper_ttm',
                    is_quarterly=False, add_data=True)
# Out:
# Field [PCF_J] is overwritten.
# Variable [ncf_oper_ttm] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query_lb_dailyindicator...
# {'fields': 'trade_date,ncf_oper_ttm,symbol'}
# 下载进度398/1219.
# 下载进度796/1219.
# 下载进度1194/1219.
# WARNING: some data is unavailable:
#     At fields 000024.SZ, 000522.SZ, 000527.SZ, 000562.SZ, 000748.SZ, 600005.SH, 600832.SH, 601268.SH, 601299.SH
# Query data - daily fields prepared.

# %%
#------------------------------ 预处理数据 ---------------------------#

# %%
id_zz800 = dp.daily_index_cons(api, '000906.SH', start, end)

# %%
mask = ~id_zz800

# %%
import numpy as np

def limit_up_down():
    trade_status = dv.get_ts('trade_status').fillna(0)
    mask_sus = trade_status == 0
    # 涨停
    up_limit = dv.add_formula('up_limit', '(close - Delay(close, 1)) / Delay(close, 1) > 0.095', is_quarterly=False)
    # 跌停
    down_limit = dv.add_formula('down_limit', '(close - Delay(close, 1)) / Delay(close, 1) < -0.095', is_quarterly=False)
    can_enter = np.logical_and(up_limit < 1, ~mask_sus) # 未涨停未停牌
    can_exit = np.logical_and(down_limit < 1, ~mask_sus) # 未跌停未停牌
    return can_enter,can_exit

can_enter, can_exit = limit_up_down()

# %%
signals = ['alpha13', 'alpha39', 'alpha109', 'alpha131', 'alpha132', 'alpha169','EquityTRate_J','PCF_J']
price = dv.get_ts('close_adj')
sw1 = sw1_name
enter = can_enter
exit = can_exit
mask = mask

# %%
from jaqs_fxdayu.research.signaldigger.process import neutralize

neutralize_dict = {a: neutralize(factor_df = dv.get_ts(a), group = dv.get_ts("sw1")) for a in signals}

# %%
#------------------------- 分析因子周期特点 ----------------------#

# %%
import matplotlib.pyplot as plt
from jaqs_fxdayu.research import SignalDigger
from jaqs_fxdayu.research.signaldigger import analysis

def cal_obj(signal, name, period, quantile):
#     price_bench = dv.data_benchmark
    obj = SignalDigger(output_folder="zz800/%s" % name,
                       output_format='pdf')
    obj.process_signal_before_analysis(signal,
                                   price=price,
                                   n_quantiles=quantile, period=period,
                                   mask=mask,
                                   group=sw1,
                                   can_enter = enter,
                                   can_exit = exit,
                                   commission = 0.0008
                                   )
    obj.create_full_report()
    return obj

def plot_pfm(signal, name, period=5, quantile=5):
    obj = cal_obj(signal, name, period, quantile)
    plt.show()
def signal_data(signal, name, period=5, quantile=5):
    obj = cal_obj(signal, name, period, quantile)
    return obj.signal_data

# %%
signals_dict = {a: signal_data(neutralize_dict[a],a,20) for a in signals}
# Out:
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 61%
#
#
# Value of signals of Different Quantiles Statistics
#                min       max      mean       std   count    count %
# quantile
# 1        -6.090076 -0.009448 -0.114684  0.164185  181233  20.054398
# 2        -0.466091  0.026317 -0.017582  0.020343  180742  20.000066
# 3        -0.268156  0.100164  0.003797  0.010435  180736  19.999402
# 4        -0.140360  0.362145  0.025425  0.019401  180742  20.000066
# 5         0.015485  8.587714  0.105894  0.137526  180254  19.946067
# Figure saved: C:\Users\LYZ\大鱼\因子复现--example\zz800\alpha13\returns_report.pdf
# Information Analysis
#                 ic
# IC Mean      0.004
# IC Std.      0.066
# t-stat(IC)   1.939
# p-value(IC)  0.053
# IC Skew      0.380
# IC Kurtosis  1.197
# Ann. IR      0.056
# Figure saved: C:\Users\LYZ\大鱼\因子复现--example\zz800\alpha13\information_report.pdf
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 50%
#
#
# ...

# %%
import pandas as pd
ic_pn = pd.Panel({a:analysis.ic_stats(signals_dict[a]) for a in signals_dict.keys()})

# %%
factor_performance = round(ic_pn.minor_xs('return_ic'),2)
print(factor_performance)
# Out:
#              EquityTRate_J  PCF_J  alpha109  alpha13  alpha131  alpha132  \
# IC Mean               0.01   0.01     -0.02     0.00     -0.01     -0.06
# IC Std.               0.08   0.07      0.08     0.07      0.10      0.11
# t-stat(IC)            5.18   5.78     -7.07     1.94     -3.69    -18.78
# p-value(IC)           0.00   0.00      0.00     0.05      0.00      0.00
# IC Skew              -0.07   0.04     -0.27     0.38     -0.02      0.50
# IC Kurtosis           0.75  -0.15      0.30     1.20     -0.24     -0.34
# Ann. IR               0.15   0.17     -0.20     0.06     -0.11     -0.54
#
#              alpha169  alpha39
# IC Mean         -0.02     0.02
# IC Std.          0.08     0.10
# t-stat(IC)      -8.76     5.18
# p-value(IC)      0.00     0.00
# IC Skew          0.16     0.36
# IC Kurtosis      0.31     0.58
# Ann. IR         -0.25     0.16

# %%
factor_IR = factor_performance.loc["Ann. IR"]
factor_IC = factor_performance.loc["IC Mean"]

# %%
good_factor = factor_IC[(factor_IC.abs() >= 0.03) & (factor_IR.abs() >=0.25)]
good_factor
# Out:
# alpha132   -0.06
# Name: IC Mean, dtype: float64

# %%
good_factor_dict = {g: float('%.2f' % good_factor[g]) for g in good_factor.index}
good_factor_dict
# Out:
# {'alpha132': -0.06}

# %%
#---------------------------- 查看因子行业特点 ---------------------------#

# %%
signal_dict = {factor: signal_data(dv.get_ts(factor), factor, period=20, quantile=5) for factor in good_factor.index}
# Out:
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 61%
#
#
# Value of signals of Different Quantiles Statistics
#                    min           max          mean           std   count  \
# quantile
# 1         0.000000e+00  1.954157e+09  7.128480e+07  7.051543e+07  181223
# 2         2.189974e+07  2.862471e+09  1.290481e+08  1.172728e+08  180726
# 3         3.864012e+07  3.914009e+09  2.026811e+08  1.777182e+08  180735
# 4         6.449334e+07  6.330171e+09  3.349592e+08  2.914170e+08  180726
# 5         1.239934e+08  2.684951e+10  9.465989e+08  1.276010e+09  180240
#
#             count %
# quantile
# 1         20.054557
# 2         19.999557
# 3         20.000553
# 4         19.999557
# 5         19.945775
# Figure saved: C:\Users\LYZ\大鱼\因子复现--example\zz800\alpha132\returns_report.pdf
# Information Analysis
#                  ic
# IC Mean      -0.081
# IC Std.       0.159
# t-stat(IC)  -17.587
# p-value(IC)   0.000
# IC Skew       0.339
# IC Kurtosis  -0.026
# ...

# %%
def ic_length(signal, days=750):
    return signal.loc[signal.index.levels[0][-days]:]

# %%
from jaqs.research.signaldigger import performance as pfm

performance_dict = {}
for factor in good_factor.index:
    ic = pfm.calc_signal_ic(ic_length(signal_dict[factor]),by_group=True)
    mean_ic_by_group = pfm.mean_information_coefficient(ic, by_group=True)
    performance_dict[factor] = round(mean_ic_by_group,2)

performance_dict
# Out:
# {'alpha132':          ic
#  group
#  交通运输  -0.14
#  休闲服务  -0.04
#  传媒    -0.10
#  公用事业  -0.06
#  农林牧渔  -0.19
#  化工    -0.07
#  医药生物  -0.06
#  商业贸易  -0.09
#  国防军工  -0.07
#  家用电器   0.01
#  建筑材料  -0.09
#  建筑装饰  -0.05
#  房地产   -0.08
#  有色金属  -0.09
#  机械设备  -0.14
#  汽车    -0.06
#  电子    -0.03
#  电气设备  -0.07
#  纺织服装  -0.05
#  综合    -0.03
#  计算机   -0.08
#  轻工制造  -0.10
#  通信    -0.00
#  采掘    -0.10
#  钢铁    -0.10
#  银行     0.04
#  非银金融  -0.08
#  食品饮料   0.09}

# %%
ic_industry = pd.Panel(performance_dict).minor_xs('ic')
ic_industry
# Out:
#        alpha132
# group
# 交通运输      -0.14
# 休闲服务      -0.04
# 传媒        -0.10
# 公用事业      -0.06
# 农林牧渔      -0.19
# 化工        -0.07
# 医药生物      -0.06
# 商业贸易      -0.09
# 国防军工      -0.07
# 家用电器       0.01
# 建筑材料      -0.09
# 建筑装饰      -0.05
# 房地产       -0.08
# 有色金属      -0.09
# 机械设备      -0.14
# 汽车        -0.06
# 电子        -0.03
# 电气设备      -0.07
# 纺织服装      -0.05
# 综合        -0.03
# 计算机       -0.08
# 轻工制造      -0.10
# 通信        -0.00
# 采掘        -0.10
# 钢铁        -0.10
# 银行         0.04
# 非银金融      -0.08
# 食品饮料       0.09

# %%
High_IC_Industry = pd.DataFrame([ic_industry[-1*ic_industry>=0.05][factor].dropna(how='all') for factor in good_factor.index]).T

# %%
alpha132 = pd.Series({'name':'alpha132','data': ['volume','close','open'] ,'IC':good_factor_dict['alpha132'],'type':'价量类','market':'ZZ800','classify':'sw1','Formula':'Ts_Mean(turnover,20)'
                    ,'parameter':[1,6],'description':'过去20天成交额均值','High_IC_Industry': {indu: float('%.2f' % High_IC_Industry['alpha132'][indu]) for indu in High_IC_Industry['alpha132'].dropna().index}})

# %%
save_excel = pd.concat([globals()[name] for name in High_IC_Industry.columns],axis=1,keys=High_IC_Industry.columns).T

# %%
save_excel
# Out:
#                        Formula  \
# alpha132  Ts_Mean(turnover,20)
#
#                                            High_IC_Industry    IC classify  \
# alpha132  {'交通运输': -0.14, '传媒': -0.1, '公用事业': -0.06, '农林... -0.06      sw1
#
#                            data description market      name parameter type
# alpha132  [volume, close, open]  过去20天成交额均值  ZZ800  alpha132    [1, 6]  价量类

# %%
save_excel.to_excel('Finish_8_factors.xlsx')
